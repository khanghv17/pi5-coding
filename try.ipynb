# %%
import numpy as np

# %%
np.random.rand(3)
# Out:
# array([0.88398622, 0.57648706, 0.15927313])

# %%
joints = []
for i in range(0, 33):
    joints.append([1,1,1])
print(len(joints))

list_skeleton = []

for i in range(0, 30):
    list_skeleton.append(joints)
print(len(list_skeleton))
# Out:
# 33
# 30

# %%
k = len(list_skeleton)
while k < 50:
    list_skeleton.appends()

# %%
arr = np.stack([np.array(j) for j in list_skeleton])
print(arr.shape)

arr3 = np.arra
# Out:
# (30, 33, 3)

# %%
arr1 = np.array(list_skeleton, dtype=np.float32)
print(arr1.shape)
# Out:
# (30, 33, 3)

# %%
user = {
    "id": 1,
    "name": "Khang",
    "age": 22
}

# %%
user["id"]
# Out:
# 1

# %%
user["url"] = "https://khang"

# %%
user
# Out:
# {'id': 1, 'name': 'Khang', 'age': 22, 'url': 'https://khang'}

# %%
class ServerResponse:
    def __init__(self, action, status, message):
        self.mac_address = "000"
        self.action = action
        self.status = status
        self.message = message
    str

# %%
k = ServerResponse("start", "success", "nothing")

# %%
import json

# %%
kstring = json.dumps(k.__dict__)
kstring
# Out:
# '{"mac_address": "000", "action": "start", "status": "success", "message": "nothing"}'

# %%
kjson = json.loads(kstring)
kjson['mac_address']
# Out:
# '000'

# %%
import cv2

cap = cv2.VideoCapture("video50.avi")

# %%
ret, frame = cap.read()

# %%
ret
# Out:
# True
